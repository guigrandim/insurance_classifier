# %% [markdown]
# # 0.0 - Imports

# %%
import pandas as pd
import os

# %% [markdown]
# ## 0.1 - Configuração dos Caminhos

# %% [markdown]
# ## 0.2 - Helper Functions

# %% [markdown]
# # 1.0 - Carregamento das Bases e Limpeza do Dataset para camada Ouro

# %% [markdown]
# ## 1.1 - Carrga a base da camada bronze

# %%
insurance_data_raw =
